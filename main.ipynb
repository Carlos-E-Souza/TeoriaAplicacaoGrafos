# %% [markdown]
# # Primeiro trabalho TAG
#
# Este projeto visa analisar estruturas de redes sociais e identificar espalhadores de notícias falsas usando algoritmos de grafos. Para realizar este trabalho, será utilizado uma metodologia de sete passos.
# 1. Definição do problema e contextualização;
# 2. Aquisição de dados;
# 3. Exploração dos dados;
# 4. Preparação dos dados;
# 5. Seleção de um algoritmo de grafos;
# 6. Otimização e ajuste fino do sistema;
# 7. Apresentação e documentação da solução.

# %%
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## 1. Definição do problema e contextualição
#
# Um dos principais problemas da atualidade e a disseminação de fake news em vários tipos de mídia. O foco deste trabalho será na rede social X(antigo twitter), queremos analisar quais pessoas que mais compartilham posts com mensagens falsas, as pessoas ou páginas que conecta diferentes comunidades(bolhas) e quem pode espalhar essa notícia com mais facilidade (Pessoa que tem mais conexões na rede).
# - Nós = usuários do twitter
# - Arestas = Retweets/mentions;
# - Atribuir pesos baseados na frequência de interação;

# %% [markdown]
# ## 2. Aquisição de dados
#
# Os dados utilizados neste trabalho serão coletados do SNAP Stanford e Kaggle

# %%
grafo = nx.petersen_graph()
subax1 = plt.subplot(121)
nx.draw(grafo, with_labels=True, font_weight='bold')
subax2 = plt.subplot(122)
nx.draw_shell(grafo, nlist=[range(5, 10), range(5)], with_labels=True, font_weight='bold')
